# %% [markdown]
# # Assignment 3

# %% [markdown]
# # Q1:
# Write a program that prompts the user for a meal: breakfast, lunch, or dinner. Then using if statements and else statements print the user a message recommending a meal. For example, if the meal was breakfast, you could say something like, “How about some bacon and eggs?” The user may enter something else in, but you only have to respond to breakfast, lunch, or dinner.

# %%
x1 = str(input("Enter desired meal: "))
meals = ["breakfast", "lunch", "dinner"]
if x in meals:
    if x == "breakfast":
        print("How about some bacon and eggs?")
    elif x == "lunch":
        print("How about some pizza?")
    elif x == "dinner":
        print("How about some salmon tacos?")
    else:
        print("Error, I don't understand what you wrote")
# Out:
# Enter desired meal: lunch
# How about some pizza?

# %% [markdown]
# # Q2:
#
# The mailroom has asked you to design a simple payroll program that calculates a student employee’s gross pay, including any overtime wages. If any employee works over 20 hours in a week, the mailroom pays them 1.5 times their regular hourly pay rate for all hours over 20.
#
# You should take in the user’s input for the number of hours worked, and their rate of pay.

# %%
number_of_hours_worked = int(input("Enter number of hours worked: "))
wage = int(input("Enter rate of pay: "))

if number_of_hours_worked <= 20:
    gross_pay = wage * number_of_hours_worked
elif number_of_hours_worked > 20:
    gross_pay = (wage*20) + wage*1.5 * (number_of_hours_worked - 20) 
print(gross_pay)
# Out:
# Enter number of hours worked: 30
# Enter rate of pay: 20
# 700.0

# %% [markdown]
# # Q3:
# Write a function named times_ten. The function should accept an argument and display the product of its argument multiplied times 10.

# %%
number = int(input("Enter number: "))
def times_ten(number):
    print(number * 10)
times_ten(10)
# Out:
# Enter number: 10
# 100

# %% [markdown]
# # Q4:
# Find the errors, debug the program, and then execute to show the output.
#
# def main() Calories1 = input( "How many calories are in the first food?") Calories2 = input( "How many calories are in the first food?") showCalories(calories1, calories2)
#
# def showCalories()
# print(“The total calories you ate today”, format(calories1 + calories2,.2f))

# %%
#inserted : after def main()
def main(): 
    # inserted int for each Calories1 and Calories2
    Calories1 = int(input("How many calories are in the first food? "))
    Calories2 = int(input("How many calories are in the second food? ")) 
    #capitalized the first letter to match the variable
    showCalories(Calories1, Calories2)
# Used Calories1 and Calories 2 as arguments in second function; inserted : after def showCalories()
def showCalories(Calories1, Calories2):
    print("The total calories you ate today", format(Calories1 + Calories2, ".2f"))

# %%
main()
# Out:
# How many calories are in the first food? 50
# How many calories are in the second food? 40
# The total calories you ate today 90.00

# %% [markdown]
# # Q5:
# Write a program that uses any loop (while or for) that calculates the total of the following series of numbers: 1/30 + 2/29 + 3/28 ............. + 30/1

# %%
def sum_of_numbers():
    total = 0
    numbers = range(1,31)
    numbers2 = range(30,0, -1)
    for i in numbers:
        total += (i/numbers2[i-1])

    print(total)

# %%
sum_of_numbers()
# Out:
# 93.84460105853213

# %% [markdown]
# # Q6:
# Write a function that computes the area of a triangle given its base and height. The formula for an area of a triangle is: AREA = 1/2 * BASE * HEIGHT
#
# For example, if the base was 5 and the height was 4, the area would be 10. triangle_area(5, 4) # should print 10

# %%
def area_of_triangle():
    base = int(input("Enter base of triangle: "))
    height = int(input("Enter height of triangle: "))
    print(base*height/2)

# %%
area_of_triangle()
# Out:
# Enter base of triangle: 8
# Enter height of triangle: 9
# 36.0
